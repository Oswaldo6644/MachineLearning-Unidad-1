# %% [markdown]
# # Limpieza de datos de netflix-movies

# %%
# Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings

# %%
# Importar drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Leer el archivo csv
df = pd.read_csv('/gdrive/MyDrive/MachineLearning/DataSciencie/Pandas/Practicas_clase_tech/netflix_titles.csv')

# Mostrar dataset
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Ver variables, para poder verificar si los datos estan completos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### **Podemos ver que los datos no estan completos**

# %%
# Veremos que porcentaje de datos del dataset faltan
# df.isnull().sum().sum()
print(f"Registros faltantes: {df.isnull().sum().sum()}, Porcentaje: {df.isnull().sum().sum()/len(df) * 100 }")
# Out:
# Registros faltantes: 4307, Porcentaje: 48.904280685818094

# %% [markdown]
# ###### **Como vemos el porcentaje de los datos es de casi el 45% es muy alto lo cual no es recomendable borrarlos**
#
# ###### **Vamos a vorrar los datos faltantes para que el data set quede limpio**

# %%
# Funciones de eliminacion de valores faltantes
df.dropna(inplace=True)
print(f"Registros faltantes: {df.isnull().sum().sum()}, Porcentaje: {df.isnull().sum().sum()/len(df) * 100 }")
df.info()
# Out:
# Registros faltantes: 0, Porcentaje: 0.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 541.5+ KB

# %% [markdown]
# ###### **Como podemos ver los valores quedaron muy bajos ya que eliminamos casi la mitad de ellos**

# %%
df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# ## Columnas Repetidas

# %%
# Niveles en las diferentes columnas

num_col = num_col = df._get_numeric_data().columns

cat_col =  df.select_dtypes(include=['object']).columns

for col in cat_col:
    print(f"'{col}': Tiene { df[col].nunique()} Niveles  ")
    print( df[col].unique() )
    print(" ")
# Out:
# 'show_id': Tiene 5332 Niveles
# ['s8' 's9' 's10' ... 's8805' 's8806' 's8807']
#
# 'type': Tiene 2 Niveles
# ['Movie' 'TV Show']
#
# 'title': Tiene 5332 Niveles
# ['Sankofa' 'The Great British Baking Show' 'The Starling' ... 'Zombieland'
#  'Zoom' 'Zubaan']
#
# 'director': Tiene 3945 Niveles
# ['Haile Gerima' 'Andy Devonshire' 'Theodore Melfi' ... 'Majid Al Ansari'
#  'Peter Hewitt' 'Mozez Singh']
#
# 'cast': Tiene 5200 Niveles
# ['Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri'
#  'Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood'
#  "Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor"
#  ...
#  'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf'
# ...

# %% [markdown]
# ### Vamos a ver las filas que se repiten

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### Puedo ver que este set de datos esta limpio ya que no se repiten sus filas, lo cual desde el principio observe tambien que tenia muchos espacios vacios y borrar los demas datos para que fuera cuerente y estuviera a la medida con toda la cantidad de datos no lo veia conveniente
#
# ###### Este dataset esta diferente al que trabajamos en clase, hablando del tamaño y no habia muchos datos numericos para poder ver alguna irregularidad en los datos, me falto entender un poco mas el como manupular los datos y ver que se debe de borrar y modificar para que el set de datos quede limpio en su totalidad
